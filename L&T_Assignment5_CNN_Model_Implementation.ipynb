# %% [markdown]
# <a href="https://colab.research.google.com/github/CoiferousYogi/BK-Birla_L-T_ML_Assignments/blob/main/L%26T_Assignment5_CNN_Model_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OCR(Optical Character Recognition) for Doctor's Prescription.
#
# ### Building a Convolutional Neural Network for Optical Character Recognition System to identify key words in handwritten prescriptions.
#
# **Here is the link to the dataset:** https://www.kaggle.com/datasets/mamun1113/doctors-handwritten-prescription-bd-dataset/data
#
# **Here is the link to the Github repository:** https://github.com/CoiferousYogi/BK-Birla_L-T_ML_Assignments/blob/main/L%26T_Assignment5_CNN_Model_Implementation.ipynb
#
# **Please refer the GitHub repository for the complete file output**

# %% [markdown]
# ###The OCR system aims to identify key information in handwritten prescriptions automatically, such as medication names and dosages, improving the efficiency and accuracy of the prescription fulfillment process.###
#
# ###The project utilizes a Convolutional Neural Network (CNN) model, leveraging the power of deep learning for image recognition. It is trained on a dataset of handwritten prescriptions, specifically the "Doctor's Handwritten Prescription BD dataset" available on Kaggle. The dataset contains images of prescription words and their corresponding labels.###

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
mamun1113_doctors_handwritten_prescription_bd_dataset_path = kagglehub.dataset_download('mamun1113/doctors-handwritten-prescription-bd-dataset')

print('Data source import complete.')
# Out:
# Data source import complete.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mamun1113/doctors-handwritten-prescription-bd-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/doctors-handwritten-prescription-bd-dataset

# %% [markdown]
# ## Using a simple Artificial Neural Network

# %%
import pandas as pd
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.applications import EfficientNetV2S
from sklearn.metrics import f1_score
import warnings
warnings.filterwarnings("ignore")

# Configuration
class Config:
    BATCH_SIZE = 16  # Reduced batch size to improve generalization
    EPOCHS = 40
    EARLY_STOPPING_PATIENCE = 5  # Stop training if validation doesn't improve
    IMG_SIZE = 224
    MEAN = [0.485, 0.456, 0.406]
    STD = [0.229, 0.224, 0.225]
    LR = 5e-4  # Reduced learning rate to prevent quick overfitting
    WEIGHT_DECAY = 1e-3  # Increased weight decay for more regularization
    MODEL_SAVE_PATH = 'best_model.keras'
    DROPOUT_RATE = 0.5  # Increased dropout for regularization

cfg = Config()
print(f"Using TensorFlow version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")

# Custom data generator class for TensorFlow
class PrescriptionDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, data_dir, label_path, batch_size=16, img_size=224,
                 is_training=False, class_to_idx=None):
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.img_size = img_size
        self.is_training = is_training

        # Check if data directory exists
        if not os.path.exists(data_dir):
            raise FileNotFoundError(f"Data directory not found: {data_dir}")

        # Check if label file exists
        if not os.path.exists(label_path):
            raise FileNotFoundError(f"Label file not found: {label_path}")

        # Load and validate data
        try:
            # Try first with header
            self.df = pd.read_csv(label_path)
            # Check if columns exist, if not try reading without header
            if 'IMAGE' not in self.df.columns:
                self.df = pd.read_csv(label_path, header=None,
                                    names=['IMAGE', 'MEDICINE_NAME', 'GENERIC_NAME'])
        except Exception as e:
            print(f"Error in initial CSV loading, trying alternative format: {str(e)}")
            try:
                # Alternative: skip first row and assign column names
                self.df = pd.read_csv(label_path, skiprows=1,
                                    names=['IMAGE', 'MEDICINE_NAME', 'GENERIC_NAME'])
            except Exception as e2:
                raise ValueError(f"Failed to load CSV: {str(e2)}")

        # Clean up data
        self.df = self.df.dropna(subset=['IMAGE', 'MEDICINE_NAME'])
        self.df = self.df.apply(lambda x: x.str.strip() if x.dtype == 'object' else x)

        # File extension handling
        self.df['IMAGE'] = self.df['IMAGE'].apply(
            lambda x: f"{x}.png" if not str(x).lower().endswith(('.png', '.jpg', '.jpeg')) else x
        )

        # Validate images
        self.valid_samples = []
        missing_files = []
        for idx, row in self.df.iterrows():
            img_path = os.path.join(data_dir, row['IMAGE'])
            if os.path.exists(img_path):
                self.valid_samples.append(row)
            else:
                missing_files.append(img_path)

        if missing_files:
            print(f"Warning: {len(missing_files)} missing image files")
            if len(missing_files) < 5:  # Show a few examples
                print(f"Examples: {missing_files[:3]}")

        self.df = pd.DataFrame(self.valid_samples)
        if len(self.df) == 0:
            raise ValueError(f"No valid images found in {data_dir}")

        # Class handling
        if class_to_idx:
            self.class_to_idx = class_to_idx
            self.classes = list(class_to_idx.keys())
            self.idx_to_class = {v: k for k, v in class_to_idx.items()}
            # Keep only samples with labels in provided classes
            self.df = self.df[self.df['MEDICINE_NAME'].isin(self.classes)]
            if len(self.df) == 0:
                raise ValueError(f"No valid samples found with provided class labels in {data_dir}")
        else:
            self.classes = sorted(self.df['MEDICINE_NAME'].unique())
            self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
            self.idx_to_class = {idx: cls for cls, idx in self.class_to_idx.items()}

        print(f"\nLoaded {len(self)} batches from {data_dir}")
        print(f"Classes: {len(self.classes)}")
        print("Class distribution:")
        class_dist = self.df['MEDICINE_NAME'].value_counts()
        print(class_dist.head())

        # Check for class imbalance
        if len(class_dist) > 1:
            min_samples = class_dist.min()
            max_samples = class_dist.max()
            if max_samples > 5 * min_samples:
                print(f"Warning: Significant class imbalance detected. Min: {min_samples}, Max: {max_samples}")

        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.df) / self.batch_size))

    def __getitem__(self, idx):
        # Get batch indices
        start_idx = idx * self.batch_size
        end_idx = min((idx + 1) * self.batch_size, len(self.df))
        batch_indices = self.indices[start_idx:end_idx]

        # Initialize batch arrays
        batch_imgs = np.zeros((end_idx - start_idx, self.img_size, self.img_size, 3), dtype=np.float32)
        batch_labels = np.zeros((end_idx - start_idx), dtype=np.int32)

        # Fill batch
        for i, index in enumerate(batch_indices):
            row = self.df.iloc[index]
            img_path = os.path.join(self.data_dir, row['IMAGE'])

            try:
                # Read and preprocess image
                img = cv2.imread(img_path)
                if img is None:
                    raise FileNotFoundError(f"Could not load {img_path}")
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, (self.img_size, self.img_size))

                # Apply augmentations if training
                if self.is_training:
                    # Random flip
                    if np.random.random() > 0.5:
                        img = cv2.flip(img, 1)  # Horizontal flip

                    if np.random.random() > 0.7:
                        img = cv2.flip(img, 0)  # Vertical flip

                    # Random rotation
                    if np.random.random() > 0.5:
                        angle = np.random.randint(0, 4) * 90
                        if angle > 0:
                            (h, w) = img.shape[:2]
                            center = (w // 2, h // 2)
                            M = cv2.getRotationMatrix2D(center, angle, 1.0)
                            img = cv2.warpAffine(img, M, (w, h))

                    # Random brightness and contrast
                    if np.random.random() > 0.3:
                        alpha = 1.0 + 0.2 * (np.random.random() - 0.5)  # Contrast
                        beta = 0.2 * (np.random.random() - 0.5) * 127    # Brightness
                        img = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)

                    # Gaussian blur
                    if np.random.random() > 0.7:
                        img = cv2.GaussianBlur(img, (5, 5), 0)

                    # Add noise
                    if np.random.random() > 0.8:
                        noise = np.random.normal(0, 10, img.shape).astype(np.uint8)
                        img = cv2.add(img, noise)

                    # Shift, scale, rotate
                    if np.random.random() > 0.5:
                        rows, cols = img.shape[:2]
                        # Random shift
                        tx = np.random.uniform(-0.1, 0.1) * cols
                        ty = np.random.uniform(-0.1, 0.1) * rows
                        # Random scale
                        scale = np.random.uniform(0.8, 1.2)
                        # Random rotation (small angles)
                        angle = np.random.uniform(-15, 15)

                        M = cv2.getRotationMatrix2D((cols/2, rows/2), angle, scale)
                        M[0, 2] += tx
                        M[1, 2] += ty
                        img = cv2.warpAffine(img, M, (cols, rows))

                # Normalize
                img = img.astype(np.float32) / 255.0
                img = (img - np.array(cfg.MEAN)) / np.array(cfg.STD)

                batch_imgs[i] = img
                batch_labels[i] = self.class_to_idx[row['MEDICINE_NAME']]

            except Exception as e:
                print(f"Error processing image {img_path}: {str(e)}")
                # Use zeros for image and keep moving
                batch_imgs[i] = np.zeros((self.img_size, self.img_size, 3), dtype=np.float32)
                batch_labels[i] = self.class_to_idx[row['MEDICINE_NAME']]

        # One-hot encode labels
        batch_labels_one_hot = tf.keras.utils.to_categorical(
            batch_labels, num_classes=len(self.classes)
        )

        return batch_imgs, batch_labels_one_hot

    def on_epoch_end(self):
        # Shuffle indices at the end of each epoch for training
        self.indices = np.arange(len(self.df))
        if self.is_training:
            np.random.shuffle(self.indices)


def create_ANN_model(num_classes):
    try:
        model = models.Sequential([
            layers.Input(shape=(cfg.IMG_SIZE, cfg.IMG_SIZE, 3)),
            layers.Flatten(),  # Flatten image into vector
            layers.Dense(512, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(cfg.DROPOUT_RATE),
            layers.Dense(256, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(cfg.DROPOUT_RATE),
            layers.Dense(num_classes, activation='softmax')
        ])
        return model
    except Exception as e:
        raise RuntimeError(f"Error creating ANN model: {str(e)}")


def create_model(num_classes):
    try:
        # Load pre-trained EfficientNetV2S
        base_model = EfficientNetV2S(
            include_top=False,
            weights='imagenet',
            input_shape=(cfg.IMG_SIZE, cfg.IMG_SIZE, 3),
            pooling='avg'
        )

        # Freeze early layers to prevent overfitting
        for layer in base_model.layers[:100]:
            layer.trainable = False

        # Create model
        model = models.Sequential([
            base_model,
            layers.Dropout(cfg.DROPOUT_RATE),
            layers.Dense(640, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(cfg.DROPOUT_RATE),
            layers.Dense(num_classes, activation='softmax')
        ])

        return model
    except Exception as e:
        raise RuntimeError(f"Error creating model: {str(e)}")

def train_model(train_gen, val_gen, num_classes):
    # Create model
    model = create_ANN_model(num_classes)

    # Compile model with label smoothing
    optimizer = optimizers.Adam(
        learning_rate=cfg.LR,
        weight_decay=cfg.WEIGHT_DECAY
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    model.summary()

    # Callbacks
    checkpoint_cb = callbacks.ModelCheckpoint(
        cfg.MODEL_SAVE_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )

    early_stopping_cb = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=cfg.EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr_cb = callbacks.ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.3,
        patience=2,
        min_lr=1e-6,
        verbose=1
    )

    # Custom callback to monitor overfitting
    class OverfitMonitor(callbacks.Callback):
        def on_epoch_end(self, epoch, logs=None):
            if epoch > 3:
                train_acc = logs.get('accuracy')
                val_acc = logs.get('val_accuracy')

                if train_acc - val_acc > 0.2:
                    print(f"\nWarning: Training accuracy ({train_acc:.4f}) much higher than validation accuracy ({val_acc:.4f})")
                    print("Possible overfitting detected")

    overfitting_cb = OverfitMonitor()

    # Train model
    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=cfg.EPOCHS,
        callbacks=[checkpoint_cb, early_stopping_cb, reduce_lr_cb, overfitting_cb],
        verbose=1
    )

    # Plot training history
    plt.figure(figsize=(15, 10))

    plt.subplot(2, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title("Loss")
    plt.legend()

    plt.subplot(2, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title("Accuracy")
    plt.legend()

    # Plot overfitting analysis
    plt.subplot(2, 2, 3)
    train_val_gap = [t - v for t, v in zip(history.history['accuracy'], history.history['val_accuracy'])]
    plt.plot(train_val_gap, label='Train-Val Accuracy Gap')
    plt.axhline(y=0.1, color='r', linestyle='--', label='Mild Overfitting Threshold')
    plt.axhline(y=0.2, color='r', linestyle='-', label='Severe Overfitting Threshold')
    plt.title("Overfitting Analysis")
    plt.legend()

    # Plot learning rate if it's changing
    plt.subplot(2, 2, 4)
    if 'lr' in history.history:
        plt.plot(history.history['lr'], label='Learning Rate')
        plt.title("Learning Rate")
        plt.yscale('log')
    else:
        # If learning rate history not available, plot val_loss again
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title("Validation Loss")
    plt.legend()

    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

    return model

def evaluate_model(model, test_gen, class_to_idx=None):
    # Get predictions
    y_pred_prob = model.predict(test_gen)
    y_pred = np.argmax(y_pred_prob, axis=1)

    # Get true labels (need to process entire test generator)
    true_labels = []
    for i in range(len(test_gen)):
        _, batch_labels = test_gen[i]
        true_labels.extend(np.argmax(batch_labels, axis=1))

    # Trim predictions to match true labels (may not be needed if batches align perfectly)
    y_pred = y_pred[:len(true_labels)]

    # Calculate metrics
    acc = (y_pred == true_labels).mean()
    f1 = f1_score(true_labels, y_pred, average='macro')

    print("\nFinal Test Results:")
    print(f"Accuracy: {acc:.4f}")
    print(f"F1 Score: {f1:.4f}")

    # Class-wise metrics if classes are provided
    if class_to_idx:
        idx_to_class = {v: k for k, v in class_to_idx.items()}
        class_correct = {}
        class_total = {}

        for i in range(len(y_pred)):
            label = true_labels[i]
            class_name = idx_to_class[label]

            if class_name not in class_total:
                class_total[class_name] = 0
                class_correct[class_name] = 0

            class_total[class_name] += 1
            if y_pred[i] == label:
                class_correct[class_name] += 1

        print("\nClass-wise Accuracy:")
        for class_name in class_total:
            acc = class_correct[class_name] / class_total[class_name] if class_total[class_name] > 0 else 0
            print(f"{class_name}: {acc:.4f} ({class_correct[class_name]}/{class_total[class_name]})")

    return acc, f1

def main():
    # Set random seeds for reproducibility
    seed = 42
    np.random.seed(seed)
    tf.random.set_seed(seed)

    # Dataset paths - check and modify as needed
    try:
        base_path = "/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset"
        if not os.path.exists(base_path):
            print(f"Base path not found: {base_path}")
            print("Looking for dataset in current directory...")
            # Try to find dataset in current directory or its subdirectories
            alternative_paths = [
                ".",
                "./Doctor's Handwritten Prescription BD dataset",
                "../input/doctors-handwritten-prescription-bd-dataset/Doctor's Handwritten Prescription BD dataset"
            ]

            for path in alternative_paths:
                if os.path.exists(path) and any("training" in f.lower() for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))):
                    base_path = path
                    print(f"Found dataset at: {base_path}")
                    break

        train_dir = os.path.join(base_path, "Training/training_words")
        val_dir = os.path.join(base_path, "Validation/validation_words")
        test_dir = os.path.join(base_path, "Testing/testing_words")

        train_labels = os.path.join(base_path, "Training/training_labels.csv")
        val_labels = os.path.join(base_path, "Validation/validation_labels.csv")
        test_labels = os.path.join(base_path, "Testing/testing_labels.csv")

    except Exception as e:
        print(f"Error setting up dataset paths: {str(e)}")
        raise

    # Initialize data generators with try-except blocks
    try:
        print("Initializing training data generator...")
        train_gen = PrescriptionDataGenerator(
            train_dir,
            train_labels,
            batch_size=cfg.BATCH_SIZE,
            img_size=cfg.IMG_SIZE,
            is_training=True
        )

        print("Initializing validation data generator...")
        val_gen = PrescriptionDataGenerator(
            val_dir,
            val_labels,
            batch_size=cfg.BATCH_SIZE,
            img_size=cfg.IMG_SIZE,
            is_training=False,
            class_to_idx=train_gen.class_to_idx
        )

        print("Initializing test data generator...")
        test_gen = PrescriptionDataGenerator(
            test_dir,
            test_labels,
            batch_size=cfg.BATCH_SIZE,
            img_size=cfg.IMG_SIZE,
            is_training=False,
            class_to_idx=train_gen.class_to_idx
        )
    except Exception as e:
        print(f"Data generator initialization failed: {str(e)}")
        raise

    # Start training with error handling
    try:
        print("\nStarting model training with overfitting prevention...")
        model = train_model(train_gen, val_gen, len(train_gen.class_to_idx))

        # Load best model for evaluation
        print("\nLoading best model for final evaluation...")
        best_model = tf.keras.models.load_model(cfg.MODEL_SAVE_PATH)

        print("\nEvaluating on test set...")
        test_acc, test_f1 = evaluate_model(best_model, test_gen, train_gen.class_to_idx)
        print(f"\nFinal results - Accuracy: {test_acc:.4f}, F1 Score: {test_f1:.4f}")

    except Exception as e:
        print(f"Error during training or evaluation: {str(e)}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print(f"Program failed: {str(e)}")
        import traceback
        traceback.print_exc()
# Out:
# Using TensorFlow version: 2.18.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Initializing training data generator...
#
# Loaded 195 batches from /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Training/training_words
# Classes: 78
# Class distribution:
# MEDICINE_NAME
# Aceta      40
# Ace        40
# Alatrol    40
# Amodis     40
# Atrizin    40
# Name: count, dtype: int64
# Initializing validation data generator...
#
# Loaded 49 batches from /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Validation/validation_words
# Classes: 78
# Class distribution:
# MEDICINE_NAME
# Aceta      10
# Ace        10
# Alatrol    10
# Amodis     10
# Atrizin    10
# Name: count, dtype: int64
# Initializing test data generator...
#
# Loaded 49 batches from /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Testing/testing_words
# Classes: 78
# Class distribution:
# MEDICINE_NAME
# Aceta      10
# Ace        10
# Alatrol    10
# Amodis     10
# Atrizin    10
# Name: count, dtype: int64
#
# Starting model training with overfitting prevention...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 150528)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    77,070,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 78)             │        20,046 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 77,225,294 (294.59 MB)
#  Trainable params: 77,223,758 (294.59 MB)
#  Non-trainable params: 1,536 (6.00 KB)
# Epoch 1/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.0139 - loss: 5.5589
# Epoch 1: val_accuracy improved from -inf to 0.01410, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 61s 270ms/step - accuracy: 0.0139 - loss: 5.5582 - val_accuracy: 0.0141 - val_loss: 4.5898 - learning_rate: 5.0000e-04
# Epoch 2/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.0148 - loss: 5.1141
# Epoch 2: val_accuracy improved from 0.01410 to 0.04231, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 29s 149ms/step - accuracy: 0.0148 - loss: 5.1139 - val_accuracy: 0.0423 - val_loss: 4.3737 - learning_rate: 5.0000e-04
# Epoch 3/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.0254 - loss: 5.0015
# Epoch 3: val_accuracy did not improve from 0.04231
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.0254 - loss: 5.0014 - val_accuracy: 0.0295 - val_loss: 4.1832 - learning_rate: 5.0000e-04
# Epoch 4/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.0216 - loss: 4.9177
# Epoch 4: val_accuracy improved from 0.04231 to 0.05128, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 42s 214ms/step - accuracy: 0.0216 - loss: 4.9176 - val_accuracy: 0.0513 - val_loss: 4.1685 - learning_rate: 5.0000e-04
# Epoch 5/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.0232 - loss: 4.8177
# Epoch 5: val_accuracy improved from 0.05128 to 0.05385, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 43s 219ms/step - accuracy: 0.0232 - loss: 4.8176 - val_accuracy: 0.0538 - val_loss: 4.1287 - learning_rate: 5.0000e-04
# Epoch 6/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.0221 - loss: 4.7520
# Epoch 6: val_accuracy improved from 0.05385 to 0.06538, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 34s 172ms/step - accuracy: 0.0221 - loss: 4.7520 - val_accuracy: 0.0654 - val_loss: 4.1205 - learning_rate: 5.0000e-04
# Epoch 7/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.0315 - loss: 4.6072
# Epoch 7: val_accuracy improved from 0.06538 to 0.07179, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 35s 179ms/step - accuracy: 0.0314 - loss: 4.6072 - val_accuracy: 0.0718 - val_loss: 4.0651 - learning_rate: 5.0000e-04
# Epoch 8/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.0264 - loss: 4.5923
# Epoch 8: val_accuracy improved from 0.07179 to 0.08718, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 47s 241ms/step - accuracy: 0.0264 - loss: 4.5923 - val_accuracy: 0.0872 - val_loss: 4.0272 - learning_rate: 5.0000e-04
# Epoch 9/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.0269 - loss: 4.5671
# Epoch 9: val_accuracy did not improve from 0.08718
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - accuracy: 0.0269 - loss: 4.5671 - val_accuracy: 0.0833 - val_loss: 4.0310 - learning_rate: 5.0000e-04
# Epoch 10/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.0261 - loss: 4.5752
# Epoch 10: val_accuracy did not improve from 0.08718
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - accuracy: 0.0261 - loss: 4.5750 - val_accuracy: 0.0846 - val_loss: 4.0199 - learning_rate: 5.0000e-04
# Epoch 11/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.0259 - loss: 4.5253
# Epoch 11: val_accuracy improved from 0.08718 to 0.10000, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - accuracy: 0.0259 - loss: 4.5251 - val_accuracy: 0.1000 - val_loss: 3.9902 - learning_rate: 1.5000e-04
# Epoch 12/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.0295 - loss: 4.4766
# Epoch 12: val_accuracy improved from 0.10000 to 0.11538, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 65s 254ms/step - accuracy: 0.0295 - loss: 4.4765 - val_accuracy: 0.1154 - val_loss: 3.9691 - learning_rate: 1.5000e-04
# Epoch 13/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.0352 - loss: 4.4692
# Epoch 13: val_accuracy improved from 0.11538 to 0.12308, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 37s 189ms/step - accuracy: 0.0352 - loss: 4.4692 - val_accuracy: 0.1231 - val_loss: 3.9556 - learning_rate: 1.5000e-04
# Epoch 14/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.0227 - loss: 4.4479
# Epoch 14: val_accuracy did not improve from 0.12308
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.0227 - loss: 4.4479 - val_accuracy: 0.1141 - val_loss: 3.9590 - learning_rate: 1.5000e-04
# Epoch 15/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.0319 - loss: 4.4191
# Epoch 15: val_accuracy did not improve from 0.12308
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 21s 96ms/step - accuracy: 0.0319 - loss: 4.4191 - val_accuracy: 0.1090 - val_loss: 3.9632 - learning_rate: 1.5000e-04
# Epoch 16/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.0267 - loss: 4.4470
# Epoch 16: val_accuracy improved from 0.12308 to 0.12564, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 42s 214ms/step - accuracy: 0.0267 - loss: 4.4470 - val_accuracy: 0.1256 - val_loss: 3.9375 - learning_rate: 4.5000e-05
# Epoch 17/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.0402 - loss: 4.4399
# Epoch 17: val_accuracy did not improve from 0.12564
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - accuracy: 0.0402 - loss: 4.4399 - val_accuracy: 0.1218 - val_loss: 3.9335 - learning_rate: 4.5000e-05
# Epoch 18/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.0313 - loss: 4.4453
# Epoch 18: val_accuracy did not improve from 0.12564
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - accuracy: 0.0313 - loss: 4.4453 - val_accuracy: 0.1256 - val_loss: 3.9286 - learning_rate: 4.5000e-05
# Epoch 19/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.0346 - loss: 4.4444
# Epoch 19: val_accuracy improved from 0.12564 to 0.12692, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 42s 215ms/step - accuracy: 0.0346 - loss: 4.4444 - val_accuracy: 0.1269 - val_loss: 3.9284 - learning_rate: 1.3500e-05
# Epoch 20/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.0255 - loss: 4.4291
# Epoch 20: val_accuracy did not improve from 0.12692
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 59s 95ms/step - accuracy: 0.0255 - loss: 4.4290 - val_accuracy: 0.1244 - val_loss: 3.9274 - learning_rate: 1.3500e-05
# Epoch 21/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.0396 - loss: 4.3813
# Epoch 21: val_accuracy did not improve from 0.12692
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 21s 96ms/step - accuracy: 0.0396 - loss: 4.3815 - val_accuracy: 0.1205 - val_loss: 3.9305 - learning_rate: 1.3500e-05
# Epoch 22/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.0408 - loss: 4.3871
# Epoch 22: val_accuracy did not improve from 0.12692
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - accuracy: 0.0407 - loss: 4.3872 - val_accuracy: 0.1244 - val_loss: 3.9309 - learning_rate: 4.0500e-06
# Epoch 23/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.0368 - loss: 4.4046
# Epoch 23: val_accuracy did not improve from 0.12692
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.2149999747634864e-06.
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - accuracy: 0.0368 - loss: 4.4045 - val_accuracy: 0.1231 - val_loss: 3.9286 - learning_rate: 4.0500e-06
# Epoch 24/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.0304 - loss: 4.3959
# Epoch 24: val_accuracy did not improve from 0.12692
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 19s 95ms/step - accuracy: 0.0304 - loss: 4.3961 - val_accuracy: 0.1231 - val_loss: 3.9300 - learning_rate: 1.2150e-06
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loading best model for final evaluation...
#
# Evaluating on test set...
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step
#
# Final Test Results:
# Accuracy: 0.0577
# F1 Score: 0.0267
#
# Class-wise Accuracy:
# Aceta: 0.0000 (0/10)
# Ace: 0.1000 (1/10)
# Alatrol: 0.0000 (0/10)
# Amodis: 0.3000 (3/10)
# Atrizin: 0.0000 (0/10)
# Axodin: 0.0000 (0/10)
# Azithrocin: 0.0000 (0/10)
# Azyth: 0.0000 (0/10)
# Az: 0.7000 (7/10)
# Bacaid: 0.6000 (6/10)
# Backtone: 0.0000 (0/10)
# Baclofen: 0.0000 (0/10)
# Baclon: 0.8000 (8/10)
# Bacmax: 0.0000 (0/10)
# Beklo: 0.0000 (0/10)
# Bicozin: 0.0000 (0/10)
# Canazole: 0.0000 (0/10)
# Candinil: 0.0000 (0/10)
# Cetisoft: 0.0000 (0/10)
# Conaz: 0.0000 (0/10)
# Dancel: 0.1000 (1/10)
# Denixil: 0.0000 (0/10)
# Diflu: 0.0000 (0/10)
# Dinafex: 0.1000 (1/10)
# Disopan: 0.0000 (0/10)
# Esonix: 0.0000 (0/10)
# Esoral: 0.0000 (0/10)
# Etizin: 0.0000 (0/10)
# Exium: 0.0000 (0/10)
# Fenadin: 0.0000 (0/10)
# Fexofast: 0.0000 (0/10)
# Fexo: 0.0000 (0/10)
# Filmet: 0.0000 (0/10)
# Fixal: 0.0000 (0/10)
# Flamyd: 0.2000 (2/10)
# Flexibac: 0.0000 (0/10)
# Flexilax: 0.0000 (0/10)
# Flugal: 0.5000 (5/10)
# Ketocon: 0.0000 (0/10)
# Ketoral: 0.0000 (0/10)
# Ketotab: 0.1000 (1/10)
# Ketozol: 0.0000 (0/10)
# Leptic: 0.0000 (0/10)
# Lucan-R: 0.0000 (0/10)
# Lumona: 0.0000 (0/10)
# M-Kast: 0.0000 (0/10)
# Maxima: 0.1000 (1/10)
# Maxpro: 0.1000 (1/10)
# Metro: 0.0000 (0/10)
# Metsina: 0.0000 (0/10)
# Monas: 0.0000 (0/10)
# Montair: 0.0000 (0/10)
# Montene: 0.0000 (0/10)
# Montex: 0.0000 (0/10)
# Napa Extend: 0.4000 (4/10)
# Napa: 0.0000 (0/10)
# Nexcap: 0.0000 (0/10)
# Nexum: 0.0000 (0/10)
# Nidazyl: 0.0000 (0/10)
# Nizoder: 0.2000 (2/10)
# Odmon: 0.0000 (0/10)
# Omastin: 0.0000 (0/10)
# Opton: 0.1000 (1/10)
# Progut: 0.0000 (0/10)
# Provair: 0.0000 (0/10)
# Renova: 0.0000 (0/10)
# Rhinil: 0.0000 (0/10)
# Ritch: 0.0000 (0/10)
# Rivotril: 0.0000 (0/10)
# Romycin: 0.0000 (0/10)
# Rozith: 0.0000 (0/10)
# Sergel: 0.0000 (0/10)
# Tamen: 0.0000 (0/10)
# Telfast: 0.0000 (0/10)
# Tridosil: 0.0000 (0/10)
# Trilock: 0.0000 (0/10)
# Vifas: 0.0000 (0/10)
# Zithrin: 0.1000 (1/10)
#
# Final results - Accuracy: 0.1000, F1 Score: 0.0267

# %% [markdown]
# ###Conclusions from the ANN Model:
# <ol>
# <li><b>Poor Performance:</b> The accuracy of 0.100 indicates that the model is only correctly classifying 10% of the prescription words in the test set. This is significantly lower than what would be considered acceptable for a practical application.</li>
#
# <li><b>Worse Than Random:</b> Considering that there are multiple classes in the dataset, an accuracy of 0.100 is likely worse than random guessing. This suggests that the model has not learnt any meaningful patterns from the data.</li>
#
# <li><b>Low F1 Score:</b> The very low F1 score of 0.0267 reinforces the poor performance. The F1 score considers both precision and recall, and a low value suggests that the model is struggling with both identifying the correct words and avoiding false positives.</li>
# </ol>
#
# Hence, Simple ANNs might not be the best choice for image-based tasks like this. They primarily work on flattened data, losing the spatial information present in images. CNNs are typically more suitable for image classification because they can learn features directly from the image structure.

# %% [markdown]
# ## Using a CNN

# %%
import pandas as pd
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.applications import EfficientNetV2S
from sklearn.metrics import f1_score
import warnings
warnings.filterwarnings("ignore")

# Configuration
class Config:
    BATCH_SIZE = 16  # Reduced batch size to improve generalization
    EPOCHS = 40
    EARLY_STOPPING_PATIENCE = 5  # Stop training if validation doesn't improve
    IMG_SIZE = 224
    MEAN = [0.485, 0.456, 0.406]
    STD = [0.229, 0.224, 0.225]
    LR = 5e-4  # Reduced learning rate to prevent quick overfitting
    WEIGHT_DECAY = 1e-3  # Increased weight decay for more regularization
    MODEL_SAVE_PATH = 'best_model.keras'
    DROPOUT_RATE = 0.5  # Increased dropout for regularization

cfg = Config()
print(f"Using TensorFlow version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")

# Custom data generator class for TensorFlow
class PrescriptionDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, data_dir, label_path, batch_size=16, img_size=224,
                 is_training=False, class_to_idx=None):
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.img_size = img_size
        self.is_training = is_training

        # Check if data directory exists
        if not os.path.exists(data_dir):
            raise FileNotFoundError(f"Data directory not found: {data_dir}")

        # Check if label file exists
        if not os.path.exists(label_path):
            raise FileNotFoundError(f"Label file not found: {label_path}")

        # Load and validate data
        try:
            # Try first with header
            self.df = pd.read_csv(label_path)
            # Check if columns exist, if not try reading without header
            if 'IMAGE' not in self.df.columns:
                self.df = pd.read_csv(label_path, header=None,
                                    names=['IMAGE', 'MEDICINE_NAME', 'GENERIC_NAME'])
        except Exception as e:
            print(f"Error in initial CSV loading, trying alternative format: {str(e)}")
            try:
                # Alternative: skip first row and assign column names
                self.df = pd.read_csv(label_path, skiprows=1,
                                    names=['IMAGE', 'MEDICINE_NAME', 'GENERIC_NAME'])
            except Exception as e2:
                raise ValueError(f"Failed to load CSV: {str(e2)}")

        # Clean up data
        self.df = self.df.dropna(subset=['IMAGE', 'MEDICINE_NAME'])
        self.df = self.df.apply(lambda x: x.str.strip() if x.dtype == 'object' else x)

        # File extension handling
        self.df['IMAGE'] = self.df['IMAGE'].apply(
            lambda x: f"{x}.png" if not str(x).lower().endswith(('.png', '.jpg', '.jpeg')) else x
        )

        # Validate images
        self.valid_samples = []
        missing_files = []
        for idx, row in self.df.iterrows():
            img_path = os.path.join(data_dir, row['IMAGE'])
            if os.path.exists(img_path):
                self.valid_samples.append(row)
            else:
                missing_files.append(img_path)

        if missing_files:
            print(f"Warning: {len(missing_files)} missing image files")
            if len(missing_files) < 5:  # Show a few examples
                print(f"Examples: {missing_files[:3]}")

        self.df = pd.DataFrame(self.valid_samples)
        if len(self.df) == 0:
            raise ValueError(f"No valid images found in {data_dir}")

        # Class handling
        if class_to_idx:
            self.class_to_idx = class_to_idx
            self.classes = list(class_to_idx.keys())
            self.idx_to_class = {v: k for k, v in class_to_idx.items()}
            # Keep only samples with labels in provided classes
            self.df = self.df[self.df['MEDICINE_NAME'].isin(self.classes)]
            if len(self.df) == 0:
                raise ValueError(f"No valid samples found with provided class labels in {data_dir}")
        else:
            self.classes = sorted(self.df['MEDICINE_NAME'].unique())
            self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
            self.idx_to_class = {idx: cls for cls, idx in self.class_to_idx.items()}

        print(f"\nLoaded {len(self)} batches from {data_dir}")
        print(f"Classes: {len(self.classes)}")
        print("Class distribution:")
        class_dist = self.df['MEDICINE_NAME'].value_counts()
        print(class_dist.head())

        # Check for class imbalance
        if len(class_dist) > 1:
            min_samples = class_dist.min()
            max_samples = class_dist.max()
            if max_samples > 5 * min_samples:
                print(f"Warning: Significant class imbalance detected. Min: {min_samples}, Max: {max_samples}")

        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.df) / self.batch_size))

    def __getitem__(self, idx):
        # Get batch indices
        start_idx = idx * self.batch_size
        end_idx = min((idx + 1) * self.batch_size, len(self.df))
        batch_indices = self.indices[start_idx:end_idx]

        # Initialize batch arrays
        batch_imgs = np.zeros((end_idx - start_idx, self.img_size, self.img_size, 3), dtype=np.float32)
        batch_labels = np.zeros((end_idx - start_idx), dtype=np.int32)

        # Fill batch
        for i, index in enumerate(batch_indices):
            row = self.df.iloc[index]
            img_path = os.path.join(self.data_dir, row['IMAGE'])

            try:
                # Read and preprocess image
                img = cv2.imread(img_path)
                if img is None:
                    raise FileNotFoundError(f"Could not load {img_path}")
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, (self.img_size, self.img_size))

                # Apply augmentations if training
                if self.is_training:
                    # Random flip
                    if np.random.random() > 0.5:
                        img = cv2.flip(img, 1)  # Horizontal flip

                    if np.random.random() > 0.7:
                        img = cv2.flip(img, 0)  # Vertical flip

                    # Random rotation
                    if np.random.random() > 0.5:
                        angle = np.random.randint(0, 4) * 90
                        if angle > 0:
                            (h, w) = img.shape[:2]
                            center = (w // 2, h // 2)
                            M = cv2.getRotationMatrix2D(center, angle, 1.0)
                            img = cv2.warpAffine(img, M, (w, h))

                    # Random brightness and contrast
                    if np.random.random() > 0.3:
                        alpha = 1.0 + 0.2 * (np.random.random() - 0.5)  # Contrast
                        beta = 0.2 * (np.random.random() - 0.5) * 127    # Brightness
                        img = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)

                    # Gaussian blur
                    if np.random.random() > 0.7:
                        img = cv2.GaussianBlur(img, (5, 5), 0)

                    # Add noise
                    if np.random.random() > 0.8:
                        noise = np.random.normal(0, 10, img.shape).astype(np.uint8)
                        img = cv2.add(img, noise)

                    # Shift, scale, rotate
                    if np.random.random() > 0.5:
                        rows, cols = img.shape[:2]
                        # Random shift
                        tx = np.random.uniform(-0.1, 0.1) * cols
                        ty = np.random.uniform(-0.1, 0.1) * rows
                        # Random scale
                        scale = np.random.uniform(0.8, 1.2)
                        # Random rotation (small angles)
                        angle = np.random.uniform(-15, 15)

                        M = cv2.getRotationMatrix2D((cols/2, rows/2), angle, scale)
                        M[0, 2] += tx
                        M[1, 2] += ty
                        img = cv2.warpAffine(img, M, (cols, rows))

                # Normalize
                img = img.astype(np.float32) / 255.0
                img = (img - np.array(cfg.MEAN)) / np.array(cfg.STD)

                batch_imgs[i] = img
                batch_labels[i] = self.class_to_idx[row['MEDICINE_NAME']]

            except Exception as e:
                print(f"Error processing image {img_path}: {str(e)}")
                # Use zeros for image and keep moving
                batch_imgs[i] = np.zeros((self.img_size, self.img_size, 3), dtype=np.float32)
                batch_labels[i] = self.class_to_idx[row['MEDICINE_NAME']]

        # One-hot encode labels
        batch_labels_one_hot = tf.keras.utils.to_categorical(
            batch_labels, num_classes=len(self.classes)
        )

        return batch_imgs, batch_labels_one_hot

    def on_epoch_end(self):
        # Shuffle indices at the end of each epoch for training
        self.indices = np.arange(len(self.df))
        if self.is_training:
            np.random.shuffle(self.indices)


def create_model(num_classes):
    try:
        # Load pre-trained EfficientNetV2S
        base_model = EfficientNetV2S(
            include_top=False,
            weights='imagenet',
            input_shape=(cfg.IMG_SIZE, cfg.IMG_SIZE, 3),
            pooling='avg'
        )

        # Freeze early layers to prevent overfitting
        for layer in base_model.layers[:100]:
            layer.trainable = False

        # Create model
        model = models.Sequential([
            base_model,
            layers.Dropout(cfg.DROPOUT_RATE),
            layers.Dense(640, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(cfg.DROPOUT_RATE),
            layers.Dense(num_classes, activation='softmax')
        ])

        return model
    except Exception as e:
        raise RuntimeError(f"Error creating model: {str(e)}")

def train_model(train_gen, val_gen, num_classes):
    # Create model
    model = create_model(num_classes)

    # Compile model with label smoothing
    optimizer = optimizers.Adam(
        learning_rate=cfg.LR,
        weight_decay=cfg.WEIGHT_DECAY
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    model.summary()

    # Callbacks
    checkpoint_cb = callbacks.ModelCheckpoint(
        cfg.MODEL_SAVE_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )

    early_stopping_cb = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=cfg.EARLY_STOPPING_PATIENCE,
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr_cb = callbacks.ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.3,
        patience=2,
        min_lr=1e-6,
        verbose=1
    )

    # Custom callback to monitor overfitting
    class OverfitMonitor(callbacks.Callback):
        def on_epoch_end(self, epoch, logs=None):
            if epoch > 3:
                train_acc = logs.get('accuracy')
                val_acc = logs.get('val_accuracy')

                if train_acc - val_acc > 0.2:
                    print(f"\nWarning: Training accuracy ({train_acc:.4f}) much higher than validation accuracy ({val_acc:.4f})")
                    print("Possible overfitting detected")

    overfitting_cb = OverfitMonitor()

    # Train model
    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=cfg.EPOCHS,
        callbacks=[checkpoint_cb, early_stopping_cb, reduce_lr_cb, overfitting_cb],
        verbose=1
    )

    # Plot training history
    plt.figure(figsize=(15, 10))

    plt.subplot(2, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title("Loss")
    plt.legend()

    plt.subplot(2, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title("Accuracy")
    plt.legend()

    # Plot overfitting analysis
    plt.subplot(2, 2, 3)
    train_val_gap = [t - v for t, v in zip(history.history['accuracy'], history.history['val_accuracy'])]
    plt.plot(train_val_gap, label='Train-Val Accuracy Gap')
    plt.axhline(y=0.1, color='r', linestyle='--', label='Mild Overfitting Threshold')
    plt.axhline(y=0.2, color='r', linestyle='-', label='Severe Overfitting Threshold')
    plt.title("Overfitting Analysis")
    plt.legend()

    # Plot learning rate if it's changing
    plt.subplot(2, 2, 4)
    if 'lr' in history.history:
        plt.plot(history.history['lr'], label='Learning Rate')
        plt.title("Learning Rate")
        plt.yscale('log')
    else:
        # If learning rate history not available, plot val_loss again
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title("Validation Loss")
    plt.legend()

    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

    return model

def evaluate_model(model, test_gen, class_to_idx=None):
    # Get predictions
    y_pred_prob = model.predict(test_gen)
    y_pred = np.argmax(y_pred_prob, axis=1)

    # Get true labels (need to process entire test generator)
    true_labels = []
    for i in range(len(test_gen)):
        _, batch_labels = test_gen[i]
        true_labels.extend(np.argmax(batch_labels, axis=1))

    # Trim predictions to match true labels (may not be needed if batches align perfectly)
    y_pred = y_pred[:len(true_labels)]

    # Calculate metrics
    acc = (y_pred == true_labels).mean()
    f1 = f1_score(true_labels, y_pred, average='macro')

    print("\nFinal Test Results:")
    print(f"Accuracy: {acc:.4f}")
    print(f"F1 Score: {f1:.4f}")

    # Class-wise metrics if classes are provided
    if class_to_idx:
        idx_to_class = {v: k for k, v in class_to_idx.items()}
        class_correct = {}
        class_total = {}

        for i in range(len(y_pred)):
            label = true_labels[i]
            class_name = idx_to_class[label]

            if class_name not in class_total:
                class_total[class_name] = 0
                class_correct[class_name] = 0

            class_total[class_name] += 1
            if y_pred[i] == label:
                class_correct[class_name] += 1

        print("\nClass-wise Accuracy:")
        for class_name in class_total:
            acc = class_correct[class_name] / class_total[class_name] if class_total[class_name] > 0 else 0
            print(f"{class_name}: {acc:.4f} ({class_correct[class_name]}/{class_total[class_name]})")

    return acc, f1

def main():
    # Set random seeds for reproducibility
    seed = 42
    np.random.seed(seed)
    tf.random.set_seed(seed)

    # Dataset paths - check and modify as needed
    try:
        base_path = "/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset"
        if not os.path.exists(base_path):
            print(f"Base path not found: {base_path}")
            print("Looking for dataset in current directory...")
            # Try to find dataset in current directory or its subdirectories
            alternative_paths = [
                ".",
                "./Doctor's Handwritten Prescription BD dataset",
                "../input/doctors-handwritten-prescription-bd-dataset/Doctor's Handwritten Prescription BD dataset"
            ]

            for path in alternative_paths:
                if os.path.exists(path) and any("training" in f.lower() for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))):
                    base_path = path
                    print(f"Found dataset at: {base_path}")
                    break

        train_dir = os.path.join(base_path, "Training/training_words")
        val_dir = os.path.join(base_path, "Validation/validation_words")
        test_dir = os.path.join(base_path, "Testing/testing_words")

        train_labels = os.path.join(base_path, "Training/training_labels.csv")
        val_labels = os.path.join(base_path, "Validation/validation_labels.csv")
        test_labels = os.path.join(base_path, "Testing/testing_labels.csv")

    except Exception as e:
        print(f"Error setting up dataset paths: {str(e)}")
        raise

    # Initialize data generators with try-except blocks
    try:
        print("Initializing training data generator...")
        train_gen = PrescriptionDataGenerator(
            train_dir,
            train_labels,
            batch_size=cfg.BATCH_SIZE,
            img_size=cfg.IMG_SIZE,
            is_training=True
        )

        print("Initializing validation data generator...")
        val_gen = PrescriptionDataGenerator(
            val_dir,
            val_labels,
            batch_size=cfg.BATCH_SIZE,
            img_size=cfg.IMG_SIZE,
            is_training=False,
            class_to_idx=train_gen.class_to_idx
        )

        print("Initializing test data generator...")
        test_gen = PrescriptionDataGenerator(
            test_dir,
            test_labels,
            batch_size=cfg.BATCH_SIZE,
            img_size=cfg.IMG_SIZE,
            is_training=False,
            class_to_idx=train_gen.class_to_idx
        )
    except Exception as e:
        print(f"Data generator initialization failed: {str(e)}")
        raise

    # Start training with error handling
    try:
        print("\nStarting model training with overfitting prevention...")
        model = train_model(train_gen, val_gen, len(train_gen.class_to_idx))

        # Load best model for evaluation
        print("\nLoading best model for final evaluation...")
        best_model = tf.keras.models.load_model(cfg.MODEL_SAVE_PATH)

        print("\nEvaluating on test set...")
        test_acc, test_f1 = evaluate_model(best_model, test_gen, train_gen.class_to_idx)
        print(f"\nFinal results - Accuracy: {test_acc:.4f}, F1 Score: {test_f1:.4f}")

    except Exception as e:
        print(f"Error during training or evaluation: {str(e)}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print(f"Program failed: {str(e)}")
        import traceback
        traceback.print_exc()
# Out:
# Using TensorFlow version: 2.17.1
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Initializing training data generator...
#
# Loaded 195 batches from /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Training/training_words
# Classes: 78
# Class distribution:
# MEDICINE_NAME
# Zithrin    40
# Aceta      40
# Ace        40
# Alatrol    40
# Amodis     40
# Name: count, dtype: int64
# Initializing validation data generator...
#
# Loaded 49 batches from /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Validation/validation_words
# Classes: 78
# Class distribution:
# MEDICINE_NAME
# Zithrin    10
# Aceta      10
# Ace        10
# Alatrol    10
# Amodis     10
# Name: count, dtype: int64
# Initializing test data generator...
#
# Loaded 49 batches from /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Testing/testing_words
# Classes: 78
# Class distribution:
# MEDICINE_NAME
# Zithrin    10
# Aceta      10
# Ace        10
# Alatrol    10
# Amodis     10
# Name: count, dtype: int64
#
# Starting model training with overfitting prevention...
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetv2-s (Functional)        │ (None, 1280)                │      20,331,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 640)                 │         819,840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 640)                 │           2,560 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 640)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 78)                  │          49,998 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 21,203,758 (80.89 MB)
#  Trainable params: 19,840,022 (75.68 MB)
#  Non-trainable params: 1,363,736 (5.20 MB)
# Epoch 1/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.0275 - loss: 5.6602
# Epoch 1: val_accuracy improved from -inf to 0.15000, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 151s 191ms/step - accuracy: 0.0275 - loss: 5.6592 - val_accuracy: 0.1500 - val_loss: 4.0074 - learning_rate: 5.0000e-04
# Epoch 2/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.0641 - loss: 4.7854
# Epoch 2: val_accuracy improved from 0.15000 to 0.32051, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 25s 127ms/step - accuracy: 0.0641 - loss: 4.7846 - val_accuracy: 0.3205 - val_loss: 3.0775 - learning_rate: 5.0000e-04
# Epoch 3/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.1429 - loss: 4.0833
# Epoch 3: val_accuracy improved from 0.32051 to 0.49103, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 25s 126ms/step - accuracy: 0.1431 - loss: 4.0823 - val_accuracy: 0.4910 - val_loss: 2.4055 - learning_rate: 5.0000e-04
# Epoch 4/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3065 - loss: 3.1633
# Epoch 4: val_accuracy improved from 0.49103 to 0.67436, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 25s 127ms/step - accuracy: 0.3066 - loss: 3.1631 - val_accuracy: 0.6744 - val_loss: 1.8933 - learning_rate: 5.0000e-04
# Epoch 5/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.4348 - loss: 2.6637
# Epoch 5: val_accuracy improved from 0.67436 to 0.76154, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 26s 128ms/step - accuracy: 0.4349 - loss: 2.6633 - val_accuracy: 0.7615 - val_loss: 1.7256 - learning_rate: 5.0000e-04
# Epoch 6/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5380 - loss: 2.3110
# Epoch 6: val_accuracy improved from 0.76154 to 0.80513, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 25s 127ms/step - accuracy: 0.5382 - loss: 2.3106 - val_accuracy: 0.8051 - val_loss: 1.6262 - learning_rate: 5.0000e-04
# Epoch 7/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6223 - loss: 2.0551
# Epoch 7: val_accuracy improved from 0.80513 to 0.86410, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 26s 128ms/step - accuracy: 0.6224 - loss: 2.0549 - val_accuracy: 0.8641 - val_loss: 1.4415 - learning_rate: 5.0000e-04
# Epoch 8/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.7103 - loss: 1.8216
# Epoch 8: val_accuracy improved from 0.86410 to 0.87692, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 25s 127ms/step - accuracy: 0.7103 - loss: 1.8215 - val_accuracy: 0.8769 - val_loss: 1.3931 - learning_rate: 5.0000e-04
# Epoch 9/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.7591 - loss: 1.6456
# Epoch 9: val_accuracy improved from 0.87692 to 0.89359, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 26s 128ms/step - accuracy: 0.7591 - loss: 1.6456 - val_accuracy: 0.8936 - val_loss: 1.4065 - learning_rate: 5.0000e-04
# Epoch 10/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.7952 - loss: 1.5828
# Epoch 10: val_accuracy did not improve from 0.89359
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 114ms/step - accuracy: 0.7952 - loss: 1.5827 - val_accuracy: 0.8859 - val_loss: 1.3616 - learning_rate: 5.0000e-04
# Epoch 11/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8133 - loss: 1.5312
# Epoch 11: val_accuracy improved from 0.89359 to 0.91538, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 26s 129ms/step - accuracy: 0.8133 - loss: 1.5311 - val_accuracy: 0.9154 - val_loss: 1.3319 - learning_rate: 5.0000e-04
# Epoch 12/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8357 - loss: 1.4532
# Epoch 12: val_accuracy improved from 0.91538 to 0.92436, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 28s 138ms/step - accuracy: 0.8356 - loss: 1.4532 - val_accuracy: 0.9244 - val_loss: 1.3413 - learning_rate: 5.0000e-04
# Epoch 13/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8554 - loss: 1.3864
# Epoch 13: val_accuracy did not improve from 0.92436
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 114ms/step - accuracy: 0.8553 - loss: 1.3865 - val_accuracy: 0.8987 - val_loss: 1.3504 - learning_rate: 5.0000e-04
# Epoch 14/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8658 - loss: 1.3559
# Epoch 14: val_accuracy did not improve from 0.92436
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 115ms/step - accuracy: 0.8657 - loss: 1.3560 - val_accuracy: 0.9154 - val_loss: 1.2908 - learning_rate: 5.0000e-04
# Epoch 15/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9046 - loss: 1.2762
# Epoch 15: val_accuracy did not improve from 0.92436
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 115ms/step - accuracy: 0.9046 - loss: 1.2761 - val_accuracy: 0.9244 - val_loss: 1.2538 - learning_rate: 1.5000e-04
# Epoch 16/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9159 - loss: 1.2039
# Epoch 16: val_accuracy improved from 0.92436 to 0.93462, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 25s 128ms/step - accuracy: 0.9159 - loss: 1.2038 - val_accuracy: 0.9346 - val_loss: 1.2272 - learning_rate: 1.5000e-04
# Epoch 17/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9496 - loss: 1.1379
# Epoch 17: val_accuracy improved from 0.93462 to 0.94103, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 25s 127ms/step - accuracy: 0.9496 - loss: 1.1378 - val_accuracy: 0.9410 - val_loss: 1.1611 - learning_rate: 1.5000e-04
# Epoch 18/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9532 - loss: 1.1119
# Epoch 18: val_accuracy did not improve from 0.94103
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 113ms/step - accuracy: 0.9531 - loss: 1.1120 - val_accuracy: 0.9385 - val_loss: 1.1535 - learning_rate: 1.5000e-04
# Epoch 19/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9533 - loss: 1.0998
# Epoch 19: val_accuracy did not improve from 0.94103
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 114ms/step - accuracy: 0.9532 - loss: 1.0997 - val_accuracy: 0.9346 - val_loss: 1.1402 - learning_rate: 1.5000e-04
# Epoch 20/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step0ms/step - accuracy: 0.9318 - loss: 1.140
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step/step - accuracy: 0.9507 - loss: 1.097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step/step - accuracy: 0.9522 - loss: 1.094
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9548 - loss: 1.0901
# Epoch 20: val_accuracy did not improve from 0.94103
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 114ms/step - accuracy: 0.9548 - loss: 1.0901 - val_accuracy: 0.9397 - val_loss: 1.1321 - learning_rate: 4.5000e-05
# Epoch 21/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9635 - loss: 1.0635
# Epoch 21: val_accuracy improved from 0.94103 to 0.94487, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 25s 128ms/step - accuracy: 0.9635 - loss: 1.0634 - val_accuracy: 0.9449 - val_loss: 1.1250 - learning_rate: 4.5000e-05
# Epoch 22/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9626 - loss: 1.0612
# Epoch 22: val_accuracy improved from 0.94487 to 0.94615, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 25s 126ms/step - accuracy: 0.9626 - loss: 1.0612 - val_accuracy: 0.9462 - val_loss: 1.1089 - learning_rate: 4.5000e-05
# Epoch 23/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9625 - loss: 1.0507
# Epoch 23: val_accuracy did not improve from 0.94615
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 115ms/step - accuracy: 0.9625 - loss: 1.0507 - val_accuracy: 0.9449 - val_loss: 1.1057 - learning_rate: 4.5000e-05
# Epoch 24/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9700 - loss: 1.0386
# Epoch 24: val_accuracy improved from 0.94615 to 0.95000, saving model to best_model.keras
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 25s 127ms/step - accuracy: 0.9700 - loss: 1.0387 - val_accuracy: 0.9500 - val_loss: 1.0812 - learning_rate: 4.5000e-05
# Epoch 25/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9733 - loss: 1.0361
# Epoch 25: val_accuracy did not improve from 0.95000
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 114ms/step - accuracy: 0.9733 - loss: 1.0361 - val_accuracy: 0.9436 - val_loss: 1.0962 - learning_rate: 4.5000e-05
# Epoch 26/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9668 - loss: 1.0377
# Epoch 26: val_accuracy did not improve from 0.95000
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 114ms/step - accuracy: 0.9668 - loss: 1.0377 - val_accuracy: 0.9449 - val_loss: 1.0813 - learning_rate: 4.5000e-05
# Epoch 27/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9761 - loss: 1.0279
# Epoch 27: val_accuracy did not improve from 0.95000
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 114ms/step - accuracy: 0.9761 - loss: 1.0279 - val_accuracy: 0.9462 - val_loss: 1.0779 - learning_rate: 1.3500e-05
# Epoch 28/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9712 - loss: 1.0151
# Epoch 28: val_accuracy did not improve from 0.95000
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 114ms/step - accuracy: 0.9712 - loss: 1.0152 - val_accuracy: 0.9436 - val_loss: 1.0724 - learning_rate: 1.3500e-05
# Epoch 29/40
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9716 - loss: 1.0277
# Epoch 29: val_accuracy did not improve from 0.95000
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 23s 114ms/step - accuracy: 0.9716 - loss: 1.0276 - val_accuracy: 0.9487 - val_loss: 1.0804 - learning_rate: 4.0500e-06
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Loading best model for final evaluation...
#
# Evaluating on test set...
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step
#
# Final Test Results:
# Accuracy: 0.8949
# F1 Score: 0.8912
#
# Class-wise Accuracy:
# Aceta: 1.0000 (10/10)
# Ace: 1.0000 (10/10)
# Alatrol: 0.8000 (8/10)
# Amodis: 1.0000 (10/10)
# Atrizin: 1.0000 (10/10)
# Axodin: 1.0000 (10/10)
# Azithrocin: 1.0000 (10/10)
# Azyth: 1.0000 (10/10)
# Az: 1.0000 (10/10)
# Bacaid: 1.0000 (10/10)
# Backtone: 1.0000 (10/10)
# Baclofen: 0.9000 (9/10)
# Baclon: 1.0000 (10/10)
# Bacmax: 1.0000 (10/10)
# Beklo: 0.7000 (7/10)
# Bicozin: 0.8000 (8/10)
# Canazole: 1.0000 (10/10)
# Candinil: 1.0000 (10/10)
# Cetisoft: 1.0000 (10/10)
# Conaz: 1.0000 (10/10)
# Dancel: 0.8000 (8/10)
# Denixil: 0.9000 (9/10)
# Diflu: 1.0000 (10/10)
# Dinafex: 0.7000 (7/10)
# Disopan: 0.9000 (9/10)
# Esonix: 0.6000 (6/10)
# Esoral: 0.8000 (8/10)
# Etizin: 1.0000 (10/10)
# Exium: 1.0000 (10/10)
# Fenadin: 0.6000 (6/10)
# Fexofast: 1.0000 (10/10)
# Fexo: 0.8000 (8/10)
# Filmet: 0.9000 (9/10)
# Fixal: 0.9000 (9/10)
# Flamyd: 0.9000 (9/10)
# Flexibac: 0.8000 (8/10)
# Flexilax: 0.9000 (9/10)
# Flugal: 0.8000 (8/10)
# Ketocon: 1.0000 (10/10)
# Ketoral: 1.0000 (10/10)
# Ketotab: 1.0000 (10/10)
# Ketozol: 0.9000 (9/10)
# Leptic: 1.0000 (10/10)
# Lucan-R: 1.0000 (10/10)
# Lumona: 0.8000 (8/10)
# M-Kast: 1.0000 (10/10)
# Maxima: 0.8000 (8/10)
# Maxpro: 0.9000 (9/10)
# Metro: 1.0000 (10/10)
# Metsina: 1.0000 (10/10)
# Monas: 1.0000 (10/10)
# Montair: 0.7000 (7/10)
# Montene: 0.5000 (5/10)
# Montex: 0.8000 (8/10)
# Napa Extend: 1.0000 (10/10)
# Napa: 0.7000 (7/10)
# Nexcap: 0.7000 (7/10)
# Nexum: 1.0000 (10/10)
# Nidazyl: 1.0000 (10/10)
# Nizoder: 1.0000 (10/10)
# Odmon: 0.9000 (9/10)
# Omastin: 1.0000 (10/10)
# Opton: 0.8000 (8/10)
# Progut: 1.0000 (10/10)
# Provair: 1.0000 (10/10)
# Renova: 0.5000 (5/10)
# Rhinil: 0.9000 (9/10)
# Ritch: 1.0000 (10/10)
# Rivotril: 0.7000 (7/10)
# Romycin: 1.0000 (10/10)
# Rozith: 0.9000 (9/10)
# Sergel: 0.6000 (6/10)
# Tamen: 1.0000 (10/10)
# Telfast: 1.0000 (10/10)
# Tridosil: 1.0000 (10/10)
# Trilock: 0.2000 (2/10)
# Vifas: 1.0000 (10/10)
# Zithrin: 1.0000 (10/10)
#
# Final results - Accuracy: 1.0000, F1 Score: 0.8912

# %%
import tensorflow as tf
import os
import numpy as np
import json

# Path to your saved best model
MODEL_PATH = '/kaggle/working/best_model.keras'
OUTPUT_DIR = '/kaggle/working/'

# Create output directory if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

def convert_to_tflite():
    print(f"Loading model from {MODEL_PATH}...")

    # Load the saved model
    try:
        model = tf.keras.models.load_model(MODEL_PATH)
        print("Model loaded successfully.")
    except Exception as e:
        print(f"Error loading model: {str(e)}")
        return

    # Print model summary for verification
    model.summary()

    # Define input shape based on your model
    input_shape = (1, 224, 224, 3)  # Using your Config.IMG_SIZE

    # Convert the model to TensorFlow Lite format
    print("Converting model to TFLite format...")

    # Standard float32 conversion
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    tflite_model = converter.convert()

    # Save the standard TFLite model
    standard_tflite_path = os.path.join(OUTPUT_DIR, 'prescription_model.tflite')
    with open(standard_tflite_path, 'wb') as f:
        f.write(tflite_model)
    print(f"Standard TFLite model saved to {standard_tflite_path}")
    print(f"Model size: {os.path.getsize(standard_tflite_path) / (1024 * 1024):.2f} MB")

    # Dynamic range quantization (reduces model size significantly, better for mobile)
    print("Creating dynamic range quantized model...")
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    dynamic_quantized_model = converter.convert()

    # Save the dynamic range quantized model
    dynamic_quantized_path = os.path.join(OUTPUT_DIR, 'prescription_model_dynamic_quantized.tflite')
    with open(dynamic_quantized_path, 'wb') as f:
        f.write(dynamic_quantized_model)
    print(f"Dynamic range quantized model saved to {dynamic_quantized_path}")
    print(f"Model size: {os.path.getsize(dynamic_quantized_path) / (1024 * 1024):.2f} MB")

    # Create metadata for Flutter (extract class information)
    print("Creating metadata for Flutter...")

    # Try to get class names from the model output layer
    try:
        output_layer = model.layers[-1]
        # Use output.shape instead of output_shape attribute
        output_shape = output_layer.output.shape
        num_classes = output_shape[-1]

        # Since we can't directly access class names from the model,
        # we'll create a placeholder list for the class indices
        class_indices = {f"class_{i}": i for i in range(num_classes)}

        # Create model metadata
        metadata = {
            "input_size": 224,
            "num_classes": num_classes,
            "mean": [0.485, 0.456, 0.406],  # Normalization values from your config
            "std": [0.229, 0.224, 0.225],   # Normalization values from your config
            "class_indices": class_indices
        }

        # Save metadata as JSON for easier parsing in Flutter
        metadata_path = os.path.join(OUTPUT_DIR, 'metadata.json')
        with open(metadata_path, 'w') as f:
            json.dump(metadata, f, indent=2)

        print(f"Model metadata saved to {metadata_path}")

    except Exception as e:
        print(f"Error generating metadata: {str(e)}")

        # Fallback method if the above fails
        try:
            # Try to infer from model's output shape
            model_output = model.output
            num_classes = model_output.shape[-1]

            # Create basic metadata with estimated class count
            metadata = {
                "input_size": 224,
                "num_classes": int(num_classes),
                "mean": [0.485, 0.456, 0.406],
                "std": [0.229, 0.224, 0.225],
                "class_indices": {f"class_{i}": i for i in range(int(num_classes))}
            }

            # Save metadata as JSON
            metadata_path = os.path.join(OUTPUT_DIR, 'metadata.json')
            with open(metadata_path, 'w') as f:
                json.dump(metadata, f, indent=2)

            print(f"Model metadata saved to {metadata_path} (using fallback method)")
        except Exception as e2:
            print(f"Fallback metadata generation also failed: {str(e2)}")
            print("Creating minimal metadata with assumed values...")

            # Create minimal metadata with assumed values
            minimal_metadata = {
                "input_size": 224,
                "num_classes": 2,  # Assuming binary classification as fallback
                "mean": [0.485, 0.456, 0.406],
                "std": [0.229, 0.224, 0.225],
                "class_indices": {"class_0": 0, "class_1": 1}
            }

            # Save minimal metadata
            metadata_path = os.path.join(OUTPUT_DIR, 'metadata.json')
            with open(metadata_path, 'w') as f:
                json.dump(minimal_metadata, f, indent=2)

            print(f"Minimal metadata saved to {metadata_path}")

    print("\nModel conversion complete!")
    print("\nTo use this model in Flutter:")
    print("1. Copy the TFLite models from the 'flutter_model' directory to your Flutter project's assets folder")
    print("2. Update your pubspec.yaml to include the model files")
    print("3. Use the tflite_flutter package to load and run the model")
    print("4. Remember to apply the same preprocessing to input images as during training")
    print("   - Resize to 224x224")
    print("   - Normalize using mean=[0.485, 0.456, 0.406] and std=[0.229, 0.224, 0.225]")

if __name__ == "__main__":
    convert_to_tflite()
# Out:
# Loading model from /kaggle/working/best_model.keras...
# Model loaded successfully.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetv2-s (Functional)        │ (None, 1280)                │      20,331,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 640)                 │         819,840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 640)                 │           2,560 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 640)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 78)                  │          49,998 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 60,883,804 (232.25 MB)
#  Trainable params: 19,840,022 (75.68 MB)
#  Non-trainable params: 1,363,736 (5.20 MB)
#  Optimizer params: 39,680,046 (151.37 MB)
# Converting model to TFLite format...
# Saved artifact at '/tmp/tmpdwdec0x5'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_3')
# Output Type:
#   TensorSpec(shape=(None, 78), dtype=tf.float32, name=None)
# Captures:
#   140424334134080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334141824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334143936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334137072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334139536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334138304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334151168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334154336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334149232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334150464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334160320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334159968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334162784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334157680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334161904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424310508880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334236080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334238896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334233792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334238016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334243648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334243296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334235024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334244352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424334244880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332218032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332217680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332220496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332215392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332219616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332225248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332224896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332227712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140426802257360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332227536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332299600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332302416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332297312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332301536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332307168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332306816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332309632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332304528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332308752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332309456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332381520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332384336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332379232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332383456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332389088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332388736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332391552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332386448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332390672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332391376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332463440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332466256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332461152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332465376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332471008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332465904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332473472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332222608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332472592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332475584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332543600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332542544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332544656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332544128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332549760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332549408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332552224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332547120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332551344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332557504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332609136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332608080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332610192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332609664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332615296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332614944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332617760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332612656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332616880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332618464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332707440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332706384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332708496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332707968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332713600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332713248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332711840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332710960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332715184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332470832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332789360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332788304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332790416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332789888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332716768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332796928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332797280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140426960799344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332796048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332794816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332803792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332802912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332890304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332894352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332894000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332896816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332891536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332895936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332900160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332899808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332898752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332900864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332901392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332973104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332972752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332975568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332970464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332974688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332981904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332981024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332981200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332720640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332983488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333071584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333074400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333069120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333073520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333080912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333079152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333079504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333081616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333081792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333153856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333153504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333156320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333151216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333155440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333162656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333161776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424333161952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331169984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332900512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331171568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331174384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331169104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331173504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332223312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331178784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331179488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331181424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331180896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331253840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331253488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331256304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331251200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331255424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332302768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331254368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331262112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331317968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331319904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331319552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331322368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331317088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331321488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331327648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331326944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331328880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331328704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331428080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331434592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331431776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331437056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331431952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331436176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331443392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331442512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331442688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331480224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331484272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331483920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331486736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331481632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331485856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331492016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331491312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331575888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331492544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331575712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331582576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331582224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331585040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331579936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331584160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331591376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331590496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331590672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331677360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331681408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331681056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331683872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331678592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331682992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331684576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331773552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331772496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331774608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331774080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332716064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331779360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331782176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331777072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331781296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331481456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331779184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331787984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331907264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332795520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331910960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331913776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331908496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331912896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331917120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331916768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331915712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331917824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331918352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331990064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331989712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331992528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331987424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331991648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331998864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331997984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331998160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332000096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332000448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332072160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332074976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332069696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332074096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332081488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331787808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332079552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332082192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332082368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332082896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332137696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332140512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332135408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332139632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332146848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332145968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332146144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330170560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331905152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330172144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330174960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330169680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330174080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330180240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330179536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330180064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330182000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330181472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330238032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330237680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330240496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330235392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330239616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330238560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330237504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330245952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330349200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424332079728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330352896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330355712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330350432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330354832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330356416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330360112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330362224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330362048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330428656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330435168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330434816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330437632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330432528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330436752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330443968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330443088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330443264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330497184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330501232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330500880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330503696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330498416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330502816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330508976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330508272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330642000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330509504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330641824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330648688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330643056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330646928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330646048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330650272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330657488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330656608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330759856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330763904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330763552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330766368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330761088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330765488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330771648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330806896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330805840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330807952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330807424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330813056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330812704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330815520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330810416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330814640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330813584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330820976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330820448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330921584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330928272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330927920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330651152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330925456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330929856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330936016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330987648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330985888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330986592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330988176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330993808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330993456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330996272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330991168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330995392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330993280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331088064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331088592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331087184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331092640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331092288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331095104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331089824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331094224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424331094928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329101552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329105072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329101728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329104544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329110176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329109824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329112640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329107536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329111760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329109648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329188048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329188576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329187168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329192624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329192272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329195088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329189808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329194208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329195792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329299744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329302560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329297984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329301680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329307312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329306960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329309776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329304672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329308896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329306784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329366688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329369328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329367920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329373376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329373024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329375840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329370560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329374960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329377952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329377248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329377776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329379008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329494768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329501280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329500928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329503744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329498640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329502864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329510080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329509200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329509376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329563296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329567344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329566992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329569808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329564528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329568928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329575088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329574384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329675344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329575616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329675168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329682032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329681680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329684496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329679392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329367040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329690832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329689952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329690128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329760432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329764480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329764128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329766944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329761840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329766064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329772224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329840240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329839184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329841296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329840768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329846400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329846048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329848864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329843760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329847984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329845872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329854672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329853792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329941184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329945232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329944880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329947696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329942416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329946816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329952976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330020992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330019936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330022048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330021520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330027152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330021168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330029616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330024512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330028736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330027680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330034544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328057552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328056144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328061600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328061248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328064064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328058784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328063184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328063888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328120976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328122032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328118688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328121504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328127136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328126784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328129600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328124496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328128720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328126608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328221392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328221920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328220512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328225968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328225616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328228432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328223152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328227552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328228256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328319168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328319520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328315120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328318640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328324272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328323920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328326736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328321632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328325856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328323744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328418528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328419056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328417648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328423104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328422752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328425568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328420288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328424688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328425392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328530576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328533040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328527936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328532160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329364048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328537440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328540256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328535152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328539376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328537264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328599280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328599808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328598400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328316880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328603504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328606320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328601040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328605440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328606144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328678208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328681024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328675920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328680144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328685776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328685424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328688240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328683136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328687360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328685248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328777920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328780560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328779152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328784608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328784256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328787072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328781792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328786192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328786896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328891728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328894544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328890144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328893664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328899296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328898944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328901760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328897360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328898592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328898768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329007824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329848512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329010464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329014512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329014160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329016976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329011696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329016096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329016800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326975328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326978144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326973040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326977264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326982896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326977792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326985360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326980256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326984480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326982368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327058656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327061296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327053552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327065344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327060592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327067808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328053152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327066928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327067632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327172464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327175280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327170176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327174400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327180032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327179680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327182496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327177392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327181616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327179504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327272176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327274816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327273408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327278864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327274112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327281328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327276048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327280448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327281152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327385984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327384576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327383696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327387920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327393552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327393200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327396016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327390912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327395136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327393024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327436544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327439184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327437776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327443232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327442880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327445696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327440416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327444816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327550704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327550352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327553168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327548064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327552288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327557920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327557568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327560384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327555280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327559504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327384928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327668560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327669088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327667680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327673136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327672784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327675600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327670320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327674720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327394432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327747488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327750304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327745200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327749424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327755056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327754704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327757520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327752416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327756640: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
#   140424330022048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330021520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330027152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330021168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330029616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330024512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330028736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330027680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424330034544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328057552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328056144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328061600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328061248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328064064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328058784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328063184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328063888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328120976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328122032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328118688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328121504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328127136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328126784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328129600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328124496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328128720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328126608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328221392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328221920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328220512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328225968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328225616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328228432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328223152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328227552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328228256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328319168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328319520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328315120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328318640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328324272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328323920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328326736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328321632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328325856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328323744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328418528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328419056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328417648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328423104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328422752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328425568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328420288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328424688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328425392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328530576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328533040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328527936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328532160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329364048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328537440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328540256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328535152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328539376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328537264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328599280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328599808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328598400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328316880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328603504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328606320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328601040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328605440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328606144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328678208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328681024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328675920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328680144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328685776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328685424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328688240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328683136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328687360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328685248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328777920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328780560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328779152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328784608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328784256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328787072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328781792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328786192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328786896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328891728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328894544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328890144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328893664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328899296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328898944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328901760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328897360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328898592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328898768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329007824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329848512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329010464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329014512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329014160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329016976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329011696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329016096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424329016800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326975328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326978144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326973040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326977264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326982896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326977792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326985360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326980256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326984480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326982368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327058656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327061296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327053552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327065344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327060592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327067808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424328053152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327066928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327067632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327172464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327175280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327170176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327174400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327180032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327179680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327182496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327177392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327181616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327179504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327272176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327274816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327273408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327278864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327274112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327281328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327276048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327280448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327281152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327385984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327384576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327383696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327387920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327393552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327393200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327396016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327390912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327395136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327393024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327436544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327439184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327437776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327443232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327442880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327445696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327440416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327444816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327550704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327550352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327553168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327548064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327552288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327557920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327557568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327560384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327555280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327559504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327384928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327668560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327669088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327667680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327673136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327672784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327675600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327670320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327674720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327394432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327747488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327750304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327745200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327749424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327755056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327754704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327757520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327752416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327756640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327754528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327814432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327817072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327815664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327821120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327820768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327819712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327821824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327822352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327912208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327911856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327914672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327909568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424327913792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326429008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424326429712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424324960448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424324956576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424324959040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424324960976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424324970656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140424324971360: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Dynamic range quantized model saved to /kaggle/working/prescription_model_dynamic_quantized.tflite
# Model size: 21.78 MB
# Creating metadata for Flutter...
# Model metadata saved to /kaggle/working/metadata.json
#
# Model conversion complete!
#
# To use this model in Flutter:
# 1. Copy the TFLite models from the 'flutter_model' directory to your Flutter project's assets folder
# 2. Update your pubspec.yaml to include the model files
# 3. Use the tflite_flutter package to load and run the model
# 4. Remember to apply the same preprocessing to input images as during training
#    - Resize to 224x224
#    - Normalize using mean=[0.485, 0.456, 0.406] and std=[0.229, 0.224, 0.225]

# %%
# making an app using Gradio
# !pip install update gradio
import gradio as gr
import tensorflow as tf
import numpy as np
import cv2
import functools

# Load your trained model
MODEL_PATH = 'best_model.keras'  # Update with your model path
model = tf.keras.models.load_model(MODEL_PATH)

base_path = "/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset"
train_dir = os.path.join(base_path, "Training/training_words")
train_labels = os.path.join(base_path, "Training/training_labels.csv")

# Preprocessing function (same as in your data generator)
def preprocess_image(image):
    image = cv2.resize(image, (224, 224))
    image = image.astype(np.float32) / 255.0
    image = (image - np.array([0.485, 0.456, 0.406])) / np.array([0.229, 0.224, 0.225])
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

train_gen = PrescriptionDataGenerator(train_dir, train_labels, is_training=True)


# Prediction function
def predict_prescription(image, train_gen):
    processed_image = preprocess_image(image)
    predictions = model.predict(processed_image)
    predicted_class_index = np.argmax(predictions)

    # Update this line to use your actual class names:
    class_names = list(train_gen.class_to_idx.keys())
    predicted_class_name = class_names[predicted_class_index]

    return predicted_class_name


predict_prescription_with_train_gen = functools.partial(predict_prescription, train_gen=train_gen)

iface = gr.Interface(
    fn=predict_prescription_with_train_gen,
    inputs=gr.Image(type="numpy"),
    outputs="text",
    title="Prescription Prediction",
    description="Upload an image of a prescription to get its prediction."
)

iface.launch()
# Out:
# Requirement already satisfied: update in /usr/local/lib/python3.10/dist-packages (0.0.1)
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (5.25.2)
# Requirement already satisfied: style==1.1.0 in /usr/local/lib/python3.10/dist-packages (from update) (1.1.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (22.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.115.12)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.8.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.29.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.10.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (11.0.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.11.0a2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.11.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.34.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.8.0->gradio) (2024.12.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.8.0->gradio) (14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.28.1->gradio) (3.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<3.0,>=1.0->gradio) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.12,>=2.0->gradio) (2.29.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0,>=1.0->gradio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0,>=1.0->gradio) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<3.0,>=1.0->gradio) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<3.0,>=1.0->gradio) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.3.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<3.0,>=1.0->gradio) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
#
# Loaded 195 batches from /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Training/training_words
# Classes: 78
# Class distribution:
# MEDICINE_NAME
# Zithrin    40
# Aceta      40
# Ace        40
# Alatrol    40
# Amodis     40
# Name: count, dtype: int64
# * Running on local URL:  http://127.0.0.1:7863
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# * Running on public URL: https://fec49817b8eb6524a1.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fec49817b8eb6524a1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step

# %% [markdown]
# # Conclusion:
# This project has successfully demonstrated the potential of deep learning in recognizing handwritten prescriptions.
#
# Furthermore, the model was converted to TensorFlow Lite format, paving the way for integration into mobile or web applications for easy access and widespread use.
#
# A Gradio app has also been created to quickly test out the real-world effectiveness of the model.
